# %%
import pandas as pd
import numpy as np

# %%
ls=pd.read_csv('../inside_airbnb_data/listings.csv')

# %% [markdown]
# ## Listings Clean

# %%
import re

ls.drop(columns= ['id', 'host_id','host_name', 'neighbourhood_group', 'last_review','license','reviews_per_month'], inplace=True)

def extract_info(text):
    # Extract rating
    rating_match = re.search(r'★(\d+\.\d+)', text)
    rating = float(rating_match.group(1)) if rating_match else 'unknown'
    
    # Extract number of bedrooms
    bedroom_match = re.search(r'(\d+)\sbedrooms?', text)
    bedrooms = int(bedroom_match.group(1)) if bedroom_match else 'unknown'
    
    # Extract number of baths
    bath_match = re.search(r'(\d+)\s(private\s)?baths?', text)
    baths = int(bath_match.group(1)) if bath_match else 'unknown'
    
    return rating, bedrooms, baths

# %%
ls[['rating', 'bedrooms', 'baths']] = ls['name'].apply(lambda x: pd.Series(extract_info(x)))
ls.drop(columns='name', inplace=True)
ls
# Out:
#                                           neighbourhood   latitude  longitude  \
# 0                                    Historic Anacostia  38.863390 -76.988890
# 1     Edgewood, Bloomingdale, Truxton Circle, Eckington  38.911950 -77.004560
# 2                            Capitol Hill, Lincoln Park  38.887190 -76.994720
# 3                          Eastland Gardens, Kenilworth  38.905850 -76.944690
# 4        Ivy City, Arboretum, Trinidad, Carver Langston  38.912170 -76.992490
# ...                                                 ...        ...        ...
# 6848                                 Shaw, Logan Circle  38.906922 -77.024228
# 6849               Brightwood Park, Crestwood, Petworth  38.949640 -77.016980
# 6850               Brightwood Park, Crestwood, Petworth  38.951456 -77.016104
# 6851               Brightwood Park, Crestwood, Petworth  38.951410 -77.016220
# 6852     Ivy City, Arboretum, Trinidad, Carver Langston  38.909047 -76.984541
#
#             room_type   price  minimum_nights  number_of_reviews  \
# 0        Private room    67.0              31                 84
# 1        Private room    66.0               1                495
# 2        Private room   135.0               7                 58
# 3        Private room    56.0              30                102
# 4        Private room  2500.0            1125                 30
# ...               ...     ...             ...                ...
# 6848  Entire home/apt   173.0              32                  0
# 6849     Private room    79.0               1                  0
# 6850  Entire home/apt    87.0               1                  0
# 6851  Entire home/apt    79.0               1                  0
# 6852     Private room   143.0               1                  0
#
#       calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                                  1               365                      3
# 1                                  5               252                     46
# 2                                  2               321                      6
# 3                                  2               179                      0
# 4                                  3               365                      0
# ...                              ...               ...                    ...
# 6848                             234               105                      0
# 6849                              28               267                      0
# 6850                              28               270                      0
# 6851                              28               270                      0
# 6852                               3               270                      0
#
#        rating bedrooms    baths
# 0        4.64      1.0      1.0
# 1        4.83      1.0      1.0
# 2        4.85        1  unknown
# 3        4.66        1  unknown
# 4        4.74      1.0      3.0
# ...       ...      ...      ...
# 6848  unknown        1        1
# 6849  unknown        1        1
# 6850  unknown        1        1
# 6851  unknown        1        1
# 6852  unknown        2        1
#
# [6853 rows x 13 columns]

# %% [markdown]
# ## Listing Details Clean

# %%
ls_detail
# Out:
#                        id                                       listing_url  \
# 0                    3686                 https://www.airbnb.com/rooms/3686
# 1                    3943                 https://www.airbnb.com/rooms/3943
# 2                    4197                 https://www.airbnb.com/rooms/4197
# 3                    4529                 https://www.airbnb.com/rooms/4529
# 4                    4967                 https://www.airbnb.com/rooms/4967
# ...                   ...                                               ...
# 6848  1047064894296117631  https://www.airbnb.com/rooms/1047064894296117631
# 6849  1047730533367174366  https://www.airbnb.com/rooms/1047730533367174366
# 6850  1047772826607759074  https://www.airbnb.com/rooms/1047772826607759074
# 6851  1047777612294831826  https://www.airbnb.com/rooms/1047777612294831826
# 6852  1047931080098470138  https://www.airbnb.com/rooms/1047931080098470138
#
#            scrape_id last_scraped           source  \
# 0     20231218032619   2023-12-18      city scrape
# 1     20231218032619   2023-12-18      city scrape
# 2     20231218032619   2023-12-18      city scrape
# 3     20231218032619   2023-12-18      city scrape
# 4     20231218032619   2023-12-18  previous scrape
# ...              ...          ...              ...
# 6848  20231218032619   2023-12-18      city scrape
# 6849  20231218032619   2023-12-18      city scrape
# 6850  20231218032619   2023-12-18      city scrape
# 6851  20231218032619   2023-12-18      city scrape
# 6852  20231218032619   2023-12-18      city scrape
#
#                                                    name  description  \
# 0     Home in Washington · ★4.64 · 1 bedroom · 1 bed...          NaN
# 1     Townhouse in Washington · ★4.83 · 1 bedroom · ...          NaN
# 2     Home in Washington · ★4.85 · 1 bedroom · 1 bed...          NaN
# 3     Home in Washington · ★4.66 · 1 bedroom · 1 bed...          NaN
# 4     Home in Washington · ★4.74 · 1 bedroom · 1 bed...          NaN
# ...                                                 ...          ...
# 6848  Rental unit in Washington · ★New · 1 bedroom ·...          NaN
# 6849  Home in Washington · ★New · 1 bedroom · 1 bed ...          NaN
# 6850  Rental unit in Washington · ★New · 1 bedroom ·...          NaN
# 6851  Rental unit in Washington · ★New · 1 bedroom ·...          NaN
# 6852  Bed and breakfast in Washington · ★New · 2 bed...          NaN
#
#                                   neighborhood_overview  \
# 0     We love that our neighborhood is up and coming...
# 1     This rowhouse is centrally located in the hear...
# 2     Our area, the Eastern Market neighborhood of C...
# 3     Very quiet neighborhood and it is easy accessi...
# 4                                                   NaN
# ...                                                 ...
# 6848  This furnished rental is situated in Shaw, a h...
# 6849                                           Petworth
# 6850                                                NaN
# 6851                                                NaN
# 6852                                                NaN
#
#                                             picture_url    host_id  ...  \
# 0     https://a0.muscache.com/pictures/61e02c7e-3d66...       4645  ...
# 1     https://a0.muscache.com/pictures/airflow/Hosti...       5059  ...
# 2     https://a0.muscache.com/pictures/miso/Hosting-...       5061  ...
# 3     https://a0.muscache.com/pictures/86072003/6709...       5803  ...
# 4     https://a0.muscache.com/pictures/2439810/bb320...       7086  ...
# ...                                                 ...        ...  ...
# 6848  https://a0.muscache.com/pictures/prohost-api/H...  107434423  ...
# 6849  https://a0.muscache.com/pictures/e9e7aaa1-ca9f...  437660791  ...
# 6850  https://a0.muscache.com/pictures/miso/Hosting-...  437660791  ...
# 6851  https://a0.muscache.com/pictures/3a57db34-796d...  437660791  ...
# 6852  https://a0.muscache.com/pictures/hosting/Hosti...  350603487  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 0                           4.84                   3.91                4.64
# 1                           4.91                   4.57                4.75
# 2                           4.98                   4.96                4.95
# 3                           4.93                   4.51                4.83
# 4                           4.93                   4.21                4.64
# ...                          ...                    ...                 ...
# 6848                         NaN                    NaN                 NaN
# 6849                         NaN                    NaN                 NaN
# 6850                         NaN                    NaN                 NaN
# 6851                         NaN                    NaN                 NaN
# 6852                         NaN                    NaN                 NaN
#
#                                license instant_bookable  \
# 0                                  NaN                f
# 1     Hosted License: 5007242201001033                f
# 2     Hosted License: 5007242201000749                f
# 3                               Exempt                f
# 4                                  NaN                f
# ...                                ...              ...
# 6848                               NaN                f
# 6849                            Exempt                t
# 6850                            Exempt                t
# 6851                            Exempt                t
# 6852                            Exempt                t
#
#      calculated_host_listings_count  \
# 0                                 1
# 1                                 5
# 2                                 2
# 3                                 2
# 4                                 3
# ...                             ...
# 6848                            234
# 6849                             28
# 6850                             28
# 6851                             28
# 6852                              3
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ...                                          ...
# 6848                                         234
# 6849                                           6
# 6850                                           6
# 6851                                           6
# 6852                                           0
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               1
# 1                                               5
# 2                                               2
# 3                                               2
# 4                                               3
# ...                                           ...
# 6848                                            0
# 6849                                           22
# 6850                                           22
# 6851                                           22
# 6852                                            3
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                              0              0.53
# 1                                              0              2.78
# 2                                              0              0.33
# 3                                              0              0.58
# 4                                              0              0.19
# ...                                          ...               ...
# 6848                                           0               NaN
# 6849                                           0               NaN
# 6850                                           0               NaN
# 6851                                           0               NaN
# 6852                                           0               NaN
#
# [6853 rows x 75 columns]
